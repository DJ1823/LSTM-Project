The water reflected the city lights beautifully
I sat on a bench thinking about how peaceful life can be sometimes
I took a few photos and sent them to my friends
They replied instantly asking where the place was
We planned to go together next weekend
The next morning I felt motivated to start the week with focus
I prepared a to do list and organized my files on the computer
At work I presented my progress report to my supervisor
He gave feedback and suggested a few improvements
I updated the document and emailed it to him before lunch
My colleague shared some homemade snacks and we all enjoyed them
After work I attended an online webinar about machine learning
The speaker explained neural networks with simple examples
It made me curious to learn more about artificial intelligence
I bookmarked a few websites for further study
At night I reviewed my notes and practiced coding exercises
My code didn’t run correctly at first but I fixed the syntax error
After debugging I finally got the correct output and felt happy
I realized that consistent effort always brings improvement
The following day was busy but productive
I helped a teammate solve a technical issue in his code
We tested the feature successfully before the deadline
Later I joined a virtual meeting with another department
We discussed new features to add in the next software release
In the evening I watered the plants on the balcony
The air felt cool and fresh after sunset
I made a cup of green tea and listened to my favorite playlist
My cat jumped on the table and spilled a little water on my notes
I laughed and cleaned the mess before continuing to write
Before bed I reflected on how small moments make big memories
Every day may look ordinary but it teaches something new
I promised myself to stay positive and thankful for small things
===DATASET END=== """

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'i': 2,
#  'and': 3,
#  'my': 4,
#  'a': 5,
#  'to': 6,
#  'for': 7,
#  'we': 8,
#  'in': 9,
#  'was': 10,
#  'after': 11,
#  'on': 12,
#  'about': 13,
#  'me': 14,
#  'with': 15,
#  'next': 16,
#  'it': 17,
#  'before': 18,
#  'felt': 19,
#  'day': 20,
#  'of': 21,
#  'at': 22,
#  'new': 23,
#  'went': 24,
#  'but': 25,
#  'few': 26,
#  'took': 27,
#  'some': 28,
#  'made': 29,
#  'had': 30,
#  'our': 31,
#  'from': 32,
#  'evening': 33,
#  'home': 34,
#  'morning': 35,
#  'an': 36,
#  'checked': 37,
#  'left': 38,
#  'work': 39,
#  'later': 40,
#  'his': 41,
#  'office': 42,
#  'meeting': 43,
#  'week': 44,
#  'lunch': 45,
#  'small': 46,
#  'talked': 47,
#  'dinner': 48,
#  'bed': 49,
#  'started': 50,
#  'online': 51,
#  'notes': 52,
#  'that': 53,
#  'her': 54,
#  'cup': 55,
#  'window': 56,
#  'while': 57,
#  'breakfast': 58,
#  'saw': 59,
#  'near': 60,
#  'music': 61,
#  'discussed': 62,
#  'nearby': 63,
#  'ordered': 64,
#  'returned': 65,
#  'stopped': 66,
# ...

# %%
len(tokenizer.word_index)
# Out:
# 532

# %%
input_sequences = []
for sentance in faqs.split('\n'):
   tokenized_sentance = tokenizer.texts_to_sequences([sentance])[0]

   for i in range(1,len(tokenized_sentance)):
    input_sequences.append(tokenized_sentance[:i+1])

# %%
input_sequences
# Out:
# [[84, 85],
#  [2, 86],
#  [2, 86, 87],
#  [2, 86, 87, 162],
#  [2, 86, 87, 162, 3],
#  [2, 86, 87, 162, 3, 29],
#  [2, 86, 87, 162, 3, 29, 5],
#  [2, 86, 87, 162, 3, 29, 5, 55],
#  [2, 86, 87, 162, 3, 29, 5, 55, 21],
#  [2, 86, 87, 162, 3, 29, 5, 55, 21, 163],
#  [2, 86, 87, 162, 3, 29, 5, 55, 21, 163, 18],
#  [2, 86, 87, 162, 3, 29, 5, 55, 21, 163, 18, 164],
#  [1, 165],
#  [1, 165, 88],
#  [1, 165, 88, 166],
#  [1, 165, 88, 166, 167],
#  [1, 165, 88, 166, 167, 4],
#  [1, 165, 88, 166, 167, 4, 56],
#  [1, 165, 88, 166, 167, 4, 56, 57],
#  [1, 165, 88, 166, 167, 4, 56, 57, 2],
#  [1, 165, 88, 166, 167, 4, 56, 57, 2, 37],
#  [1, 165, 88, 166, 167, 4, 56, 57, 2, 37, 4],
#  [1, 165, 88, 166, 167, 4, 56, 57, 2, 37, 4, 89],
#  [4, 168],
#  [4, 168, 169],
#  [4, 168, 169, 14],
#  [4, 168, 169, 14, 6],
#  [4, 168, 169, 14, 6, 170],
#  [4, 168, 169, 14, 6, 170, 58],
#  [4, 168, 169, 14, 6, 170, 58, 15],
#  [4, 168, 169, 14, 6, 170, 58, 15, 1],
#  [4, 168, 169, 14, 6, 170, 58, 15, 1, 171],
# ...

# %%
max_len = max([len(x)for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences,maxlen=max_len,padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  84,  85],
#        [  0,   0,   0, ...,   0,   2,  86],
#        [  0,   0,   0, ...,   2,  86,  87],
#        ...,
#        [  0,   0,   0, ..., 530,   7,  46],
#        [  0,   0,   0, ...,   7,  46, 531],
#        [  0,   0,   0, ...,   0,  84, 532]], dtype=int32)

# %%
x = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
x.shape
# Out:
# (1161, 14)

# %%
y.shape
# Out:
# (1161,)

# %%
from sklearn.model_selection import train_test_split

# Split data: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=len(tokenizer.word_index)+1)

# %%
y.shape
# Out:
# (1161, 533)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(len(tokenizer.word_index)+1,100,input_length=max_len-1))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index)+1,activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss = 'categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 14, 100)        │        53,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 533)            │        80,483 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 853,151 (3.25 MB)
#  Trainable params: 284,383 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 568,768 (2.17 MB)

# %%
history = model.fit(X_train,y_train,epochs=50,batch_size=128,validation_split=0.1)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9067 - loss: 0.2927 - val_accuracy: 0.9355 - val_loss: 0.2309
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9134 - loss: 0.2683 - val_accuracy: 0.9355 - val_loss: 0.2334
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9220 - loss: 0.2630 - val_accuracy: 0.9247 - val_loss: 0.2372
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9111 - loss: 0.2751 - val_accuracy: 0.9140 - val_loss: 0.2430
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9279 - loss: 0.2635 - val_accuracy: 0.9140 - val_loss: 0.2493
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9181 - loss: 0.2564 - val_accuracy: 0.9140 - val_loss: 0.2549
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9189 - loss: 0.2553 - val_accuracy: 0.9140 - val_loss: 0.2612
# Epoch 8/50
# ...

# %%
import matplotlib.pyplot as plt
import os

# Create a directory to save the plots
plot_dir = 'plots'
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(os.path.join(plot_dir, 'accuracy_plot.png'))
plt.show()


# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig(os.path.join(plot_dir, 'loss_plot.png'))
plt.show()

# %%
# Evaluate on unseen test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Loss: {test_loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8490 - loss: 0.6058
# Test Accuracy: 0.8583691120147705
# Test Loss: 0.5652859210968018

# %%
import time
import numpy as np

text = "i saw"

for i in range(8):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=max_len-1, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# i saw a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# i saw a man
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# i saw a man walking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# i saw a man walking his
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# i saw a man walking his dog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# i saw a man walking his dog near
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# i saw a man walking his dog near the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# i saw a man walking his dog near the park
